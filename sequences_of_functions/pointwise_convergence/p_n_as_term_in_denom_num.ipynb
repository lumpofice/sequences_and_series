# %% [markdown]
# # Pointwise Convergence
#
# ## $n$ as a term in the denominator and in the numerator
#
# Pointwise convergence for a sequence of functions $\{f_{n}\}_{n=1}^{\infty}$ gives us the ability to pinpoint where along the graph &mdash;specifically, at which $x$ within the domain of the functions&mdash; the sequence converges. By Bartle p.243, with some arbitrarily small $\epsilon$ given, at some fixed $x$ along the domain, the sequence is pointwise convergent to function $f$ at $x$ if there exists some $K \in \mathbb{N}$ such that for all $n \geq K$ we have
#
# <h1><center>
#     $\lvert f_{n}(x) - f(x) \rvert < \epsilon$
#     </center></h1>

# %%
import matplotlib.pyplot as plt
import numpy as np
import logging
logging.basicConfig(level=logging.DEBUG, format=' %(asctime)s - %(levelname)s'
    ' - %(message)s')
logging.getLogger('matplotlib.font_manager').disabled = True


logging.debug('Start of program' + f'\n')
# Out:
#  2022-06-21 17:33:19,626 - DEBUG - Start of program

# %% [markdown]
# ### Our function:
#
# <h1><center>
#     $f_{n}(x) = \dfrac{nx}{1+(nx)^2}$
#     </center></h1>
#
# which converges to $f(x) \equiv 0$. Because we wish to eventually see a figure rendered through ```matplotlib```, which will be delayed by some amount of time due to limitations in the computational power of the machine, we set some limitations for $x$ and $\epsilon$ as the program prompts. Failing to comply with these limitations will kick us out of the program. We believe the space provided for each of these variables is large enough to acheive its goal. Whether you wish to study this concept with an arbitrarily small epsilon or an aritrarily large natural number, the following lines of code give us the condition we need to evaluate as True for uniform convergence:
#
# ##### For $\epsilon > 0$ :
#
# ```python
# if abs((n*x)/(1+(n*x)**2)) < epsilon:
# ```
#
# which of course is the same as
#
# ```python
# if abs((n*x)/(1+(n*x)**2) - 0) < epsilon:
# ```
#
# Mathematically, the analysis to reach such a conclusion is as follows: We choose some $\epsilon > 0$ in terms of &mdash;and dependent upon&mdash; $K$ and $x$. By The Archimedean Property on p.42 of Bartle, there exists some natural number $K$ such that, for our fixed $x$, $ \hspace{4pt} K \lvert x \rvert > \dfrac{1}{\epsilon}$. $\hspace{4pt}$ Of course, that means $\dfrac{1}{K \lvert x \rvert} < \epsilon$ is also true. Thus, we have, for some fixed $x$
#
# <h1><center>
#     $\Big\lvert f_{n}(x) - f(x) \Big\rvert = \Big\lvert \dfrac{nx}{1+(nx)^2} - 0\Big\rvert = \Big\lvert \dfrac{nx}{1+(nx)^2} \Big\rvert \leq \Big\lvert \dfrac{nx}{(nx)^2} \Big\rvert \leq \Big\lvert \dfrac{1}{nx} \Big\rvert \leq \Big\lvert \dfrac{1}{Kx} \Big\rvert < \epsilon$
#     </center></h1>
#
# $\text{for all} \hspace{4pt} n \geq K$
#
# ##### For $K \in \mathbb{N}$ :
# ```python
# if abs((n*x)/(1+(n*x)**2)) < 1/k:
# ```
#
# which of course is the same as
#
# ```python
# if abs((n*x)/(1+(n*x)**2) - 0) < 1/k:
# ```
#
# Mathematically, the analysis to reach such a conclusion is as follows: We choose some $\epsilon > 0$ in terms of $K$, say $\epsilon = \dfrac{1}{K}$, where $K < n \lvert x \rvert$ for all $n > \dfrac{K}{\lvert x \rvert}$. Thus, we have, for some fixed $x$
#
# <h1><center>
#     $\Big\lvert f_{n}(x) - f(x) \Big\rvert = \Big\lvert \dfrac{nx}{1+(nx)^2} - 0\Big\rvert = \Big\lvert \dfrac{nx}{1+(nx)^2} \Big\rvert \leq \Big\lvert \dfrac{nx}{(nx)^2} \Big\rvert \leq \Big\lvert \dfrac{1}{nx} \Big\rvert < \dfrac{1}{K}$
#     </center></h1>
#
#
# Once the condition evaluates to True, the program plots the graph, giving us the value $M \in \mathbb{N}$ at which &mdash;and beyond, of course&mdash; the absolute value of the difference falls below $\epsilon$. For the $\epsilon$ approach $\Big($for the $\dfrac{1}{k}$ approach, replace $\epsilon$ with $\dfrac{1}{k}\Big)$, the legend on the graph includes a label $\epsilon$ and a label $x$. The former is a horizontal line that serves as graphical indicator for the condition
# ```python
# if abs((n*x)/(1+(n*x)**2)) < epsilon:
# ```
# The latter is a vertical line representing where our chosen $x$ falls along the domain. Our python program is set to run until a function within the sequence, at index $M \in \mathbb{N}$, evaluated at our chosen $x$, falls below the horizontal line represented in the graph by the value of $\epsilon$ at, or before, the $x$ value we've chosen. Even though the program stops at this point, it should be pointed out that, for every $n \geq M$, the function $f_{n}$ will fall below this $\epsilon$, at our chosen value of $x$. Zooming in on the graph may show otherwise, and we believe there may be an issue with rendering the image after some zooming threshold, since a simple computation with our chosen $x$ and the index spit out by the python function, say $N$, clearly shows $\epsilon$ to be larger than $f_{N}(x)$. The quantity $\epsilon$ represents the absolute distance from the limit, $0$.

# %%
def nx_over_one_plus_nx_squared():
    """This function plots each function $f_{n}(x)$, from a sequence of
functions \{f_{n}\}_{n=1}^{\infty}, each with a doman and codmain of real
numbers, from n=1 up to whatever value of n is required for the if conditional
to evaluate True. Once the if conditional evaluates True, the function stores
the number of natural numbers, n=K, for such an evaluation to be reached.
This sequence of functions converges pointwise to f=0, on (-\infty, \infty).
However, we observe convergence on the positive portion of the graph."""
    
    
    # We kick off the program
    starter = True
    while starter:
        
        
        # We give users a choice of whether or not they wish to explore this
        # function with a natural number or an epsilon
        choose_k_or_e = input('Would you like to choose an arbitrarily'\
                ' small number based on natural number k or positive epsilon?'\
                ' Press k for natural number k, choose e for positive epsilon,'\
                ' or press return to escape the program: \n')
        
        
        if not choose_k_or_e:
            starter = False
            return 'Okay. Goodbye'
        
            
        if choose_k_or_e == 'e':
            starter = False
        
        
            # User input for x
            flag = True
            while flag:
                
                
                x_input = input('Choose a real number x between 1/2 and 10,'\
                    ' or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not x_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    x = float(x_input)
                    # When user input for x is out of specified range
                    if x < 1/2 or x > 10:
                        logging.debug(f'Your value x={x} is not in the'\
                            ' requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
                
            
            # User input for epsilon
            flag = True
            while flag:
                
                
                epsilon_input = input('Choose a small number epsilon, between'\
                    ' 1/1000 and 1/100, or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not epsilon_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    epsilon = float(epsilon_input)
                    # When user input for epsilon is out of specified range
                    if epsilon < 1/1000 or epsilon > 1/100:
                        logging.debug(f'Your value epsilon={epsilon} is not'\
                            ' in the requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
            
            
            # The statement below begins to assemble our figure
            fig, ax = plt.subplots(figsize=(15, 10))
            
            
            # Vector u is what defines our restricted domain of each function
            # with respect to x
            u = np.linspace(0, 100, 2000)
            
            
            # We initiate the index n with a value of 1 to simulate a
            # mathematical sequence
            n = 1
            
            
            # Vector v will serve as the range of our restricted domain defined
            # by vector u
            v = (n*u)/(1+(n*u)**2)
            
            
            # We plot this first vector pair u and v.
            ax.plot(u, v)
            
            
            flag = True
            while flag:
                
                
                if abs((n*x)/(1+(n*x)**2)) < epsilon:
                    # Completing the plot
                    ax.axvline(x=0, c='k')
                    ax.axhline(y=0, c='k')
                    ax.axhline(y=epsilon, c='k', label=r'$\epsilon$')
                    ax.axvline(x=x, c='c', label='x')
                    plt.xlabel('Restricted Domain with respect to x',\
                        fontsize=20)
                    plt.xticks(fontsize=10)
                    plt.ylabel('Range of Restricted Domain',\
                        fontsize=20)
                    plt.yticks(fontsize=10)
                    plt.ylim(0, 0.02)
                    plt.xlim(0, 100 + epsilon)
                    fig.suptitle(r'$f_{n}(x) = \dfrac{nx}{1+(nx)^2}$',\
                        fontsize=20)
                    plt.legend(prop={'size':20})
                    plt.show()
                    
                    
                    flag = False
                    
                    
                else:
                    # We increase our index by 1
                    n += 1
                    
                    
                    # We keep the same restricted domain with vector u, but our
                    # range with this new vector v will change, since n has
                    # changed
                    v = (n*u)/(1+(n*u)**2)
                    
                    
                    # We plot the next vector pair u and v in the same plot as 
                    # the preceding vector pairs
                    ax.plot(u, v)
                    
                    
            return f'The number of functions on the graph: {n}'
        
        
        if choose_k_or_e == 'k':
            starter = False
        
        
            # User input for x
            flag = True
            while flag:
                
                
                x_input = input('Choose a real number x between 1/2 and 10,'\
                    ' or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not x_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    x = float(x_input)
                    # When user input for x is out of specified range
                    if x < 1/2 or x > 10:
                        logging.debug(f'Your value x={x} is not in the'\
                            ' requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
                
            
            # User input for k
            flag = True
            while flag:
                
                
                k_input = input('Choose a natural number k, between'\
                    ' 100 and 1000, or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not k_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    k = float(k_input)
                    # When user input for k is out of specified range
                    if k < 100 or k > 1000:
                        logging.debug(f'Your value k={k} is not'\
                            ' in the requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
            
            
            # The statement below begins to assemble our figure
            fig, ax = plt.subplots(figsize=(15, 10))
            
            
            # Vector u is what defines our restricted domain of each function
            # with respect to x
            u = np.linspace(0, 100, 2000)
            
            
            # We initiate the index n with a value of 1 to simulate a
            # mathematical sequence
            n = 1
            
            
            # Vector v will serve as the range of our restricted domain defined
            # by vector u
            v = (n*u)/(1+(n*u)**2)
            
            
            # We plot this first vector pair u and v.
            ax.plot(u, v)
            
            
            flag = True
            while flag:
                
                
                if abs((n*x)/(1+(n*x)**2)) < (1/k):
                    # Completing the plot
                    ax.axvline(x=0, c='k')
                    ax.axhline(y=0, c='k')
                    ax.axhline(y=(1/k), c='k', label=r'$\dfrac{1}{k}$')
                    ax.axvline(x=x, c='c', label='x')
                    plt.xlabel('Restricted Domain with respect to x',\
                        fontsize=20)
                    plt.xticks(fontsize=10)
                    plt.ylabel('Range of Restricted Domain',\
                        fontsize=20)
                    plt.yticks(fontsize=10)
                    plt.ylim(0, 0.02)
                    plt.xlim(0, 100 + (1/k))
                    fig.suptitle(r'$f_{n}(x) = \dfrac{nx}{1+(nx)^2}$',\
                        fontsize=20)
                    plt.legend(prop={'size':20})
                    plt.show()
                    
                    
                    flag = False
                    
                    
                else:
                    # We increase our index by 1
                    n += 1
                    
                    
                    # We keep the same restricted domain with vector u, but our
                    # range with this new vector v will change, since n has
                    # changed
                    v = (n*u)/(1+(n*u)**2)
                    
                    
                    # We plot the next vector pair u and v in the same plot as 
                    # the preceding vector pairs
                    ax.plot(u, v)
                    
                    
            return f'The number of functions on the graph: {n}'
        
        
        else:
            continue
            

nx_over_one_plus_nx_squared()
# Out:
# Would you like to choose an arbitrarily small number based on natural number k or positive epsilon? Press k for natural number k, choose e for positive epsilon, or press return to escape the program:
# e
# Choose a real number x between 1/2 and 10, or press the return key to quit: 0.5
# Choose a small number epsilon, between 1/1000 and 1/100, or press the return key to quit: 0.001
#  2022-06-16 11:42:20,177 - DEBUG - update_title_pos
#  2022-06-16 11:42:26,759 - DEBUG - update_title_pos
#  2022-06-16 11:42:31,628 - DEBUG - update_title_pos
#  2022-06-16 11:42:34,296 - DEBUG - update_title_pos
# 'The number of functions on the graph: 2000'

# %% [markdown]
# ### Our function:
#
# <h1><center>
#     $f_{n}(x) = \dfrac{nx}{1+(nx)}$
#     </center></h1>
#
# which converges to $f(x) \equiv 1$. Because we wish to eventually see a figure rendered through ```matplotlib```, which will be delayed by some amount of time due to limitations in the computational power of the machine, we set some limitations for $x$ and $\epsilon$ as the program prompts. Failing to comply with these limitations will kick us out of the program. We believe the space provided for each of these variables is large enough to acheive its goal. Whether you wish to study this concept with an arbitrarily small epsilon or an aritrarily large natural number, the following lines of code give us the condition we need to evaluate as True for uniform convergence:
#
# ##### For $\epsilon > 0$ :
#
# ```python
# if abs((n*x)/(1+(n*x)) - 1) < epsilon:
# ```
#
# Mathematically, the analysis to reach such a conclusion is as follows: We choose some $\epsilon > 0$ in terms of &mdash;and dependent upon&mdash; $K$ and $x$. By The Archimedean Property on p.42 of Bartle, there exists some natural number $K$ such that, for our fixed $x$, $ \hspace{4pt} K \lvert x \rvert > \dfrac{1}{\epsilon}$. $\hspace{4pt}$ Of course, that means $\dfrac{1}{K \lvert x \rvert} < \epsilon$ is also true. Thus, we have, for some fixed $x$
#
# <h1><center>
#     $\Big\lvert f_{n}(x) - f(x) \Big\rvert = \Big\lvert \dfrac{nx}{1+(nx)} - 1\Big\rvert = \Big\lvert \dfrac{1}{1+(nx)} \Big\rvert \leq \Big\lvert \dfrac{1}{nx} \Big\rvert \leq \Big\lvert \dfrac{1}{Kx} \Big\rvert < \epsilon$
#     </center></h1>
#
# $\text{for all} \hspace{4pt} n \geq K$
#
# ##### For $K \in \mathbb{N}$ :
# ```python
# if abs((n*x)/(1+(n*x)) - 1) < 1/k:
# ```
#
# Mathematically, the analysis to reach such a conclusion is as follows: We choose some $\epsilon > 0$ in terms of $K$, say $\epsilon = \dfrac{1}{K}$, where $K < n \lvert x \rvert$ for all $n > \dfrac{K}{\lvert x \rvert}$. Thus, we have, for some fixed $x$
#
# <h1><center>
#     $\Big\lvert f_{n}(x) - f(x) \Big\rvert = \Big\lvert \dfrac{nx}{1+(nx)} - 1\Big\rvert = \Big\lvert \dfrac{1}{1+(nx)} \Big\rvert \leq \Big\lvert \dfrac{1}{nx} \Big\rvert < \dfrac{1}{K}$
#     </center></h1>
#
# $\text{for all} \hspace{4pt} n > K$
#
# Once the condition evaluates to True, the program plots the graph, giving us the value $M \in \mathbb{N}$ at which &mdash;and beyond, of course&mdash; the absolute value of the difference $\Big\lvert f_{n}(x) - f(x) \Big\rvert$ falls below $\epsilon$. For the $\epsilon$ approach $\Big($for the $\dfrac{1}{k}$ approach, replace $\epsilon$ with $\dfrac{1}{k}\Big)$, the legend on the graph includes a label $\epsilon$, $1-\epsilon$, and a label $x$. The former is a horizontal line that serves as graphical indicator for the condition
# ```python
# if abs((n*x)/(1+(n*x)) - 1) < epsilon:
# ```
# The second label, $1 - \epsilon$, is the horizontal line sitting a distance $\epsilon$ from the limit, $1$. Since the limit sits above this horizontal line, we run this python function until a function in the sequence, at some index $M \in \mathbb{N}$, evaluated at our chosen $x$, falls above the horizontal line represented in the graph by the value of $1 - \epsilon$ at, or before, the $x$ value we've chosen. Even though the program stops at this point, it should be pointed out that, for every $n \geq M$, the function $f_{n}$ will fall above this $1 - \epsilon$, at our chosen value of $x$. The quantity $\epsilon$ represents the absolute distance from the limit, $1$. The latter is a vertical line representing where our chosen $x$ falls along the domain. Our python program is set to run until a function within the sequence, at index $M \in \mathbb{N}$, evaluated at our chosen $x$, falls above the horizontal line represented in the graph by the value of $1 - \epsilon$ at, or before, the $x$ value we've chosen.

# %%
def nx_over_one_plus_nx():
    """This function plots each function $f_{n}(x)$, from a sequence of
functions \{f_{n}\}_{n=1}^{\infty}, each with a doman and codmain of real
numbers, from n=1 up to whatever value of n is required for the if conditional
to evaluate True. Once the if conditional evaluates True, the function stores
the number of natural numbers, n=K, for such an evaluation to be reached.
This sequence of functions converges pointwise to f=1, on [0, \infty)."""
    
    
    # We kick off the program
    starter = True
    while starter:
        
        
        # We give users a choice of whether or not they wish to explore this
        # function with a natural number or an epsilon
        choose_k_or_e = input('Would you like to choose an arbitrarily'\
                ' small number based on natural number k or positive epsilon?'\
                ' Press k for natural number k, choose e for positive epsilon,'\
                ' or press return to escape the program: \n')
        
        
        if not choose_k_or_e:
            starter = False
            return 'Okay. Goodbye'
        
            
        if choose_k_or_e == 'e':
            starter = False
        
        
            # User input for x
            flag = True
            while flag:
                
                
                x_input = input('Choose a real number x between 1/2 and 10,'\
                    ' or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not x_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    x = float(x_input)
                    # When user input for x is out of specified range
                    if x < 1/2 or x > 10:
                        logging.debug(f'Your value x={x} is not in the'\
                            ' requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
                
            
            # User input for epsilon
            flag = True
            while flag:
                
                
                epsilon_input = input('Choose a small number epsilon, between'\
                    ' 1/1000 and 1/100, or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not epsilon_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    epsilon = float(epsilon_input)
                    # When user input for epsilon is out of specified range
                    if epsilon < 1/1000 or epsilon > 1/100:
                        logging.debug(f'Your value epsilon={epsilon} is not'\
                            ' in the requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
            
            
            # The statement below begins to assemble our figure
            fig, ax = plt.subplots(figsize=(15, 10))
            
            
            # Vector u is what defines our restricted domain of each function
            # with respect to x
            u = np.linspace(0, 10, 1000)
            
            
            # We initiate the index n with a value of 1 to simulate a
            # mathematical sequence
            n = 1
            
            
            # Vector v will serve as the range of our restricted domain defined
            # by vector u
            v = (n*u)/(1+(n*u))
            
            
            # We plot this first vector pair u and v, as well as the 
            # absolute value of the difference of f_n(x)-f(x), where f_n(x) is 
            # the function from our sequence at n=1 and f(x) is the function to 
            # which the sequence of functions converges for a fixed x.
            ax.plot(u, v)
            
            
            flag = True
            while flag:
                
                
                if abs((n*x)/(1+(n*x)) - 1) < epsilon:
                    # Completing the plot
                    ax.axvline(x=0, c='k')
                    ax.axhline(y=0, c='k')
                    ax.axhline(y=1-epsilon, c='k', label=r'$1-\epsilon$')
                    ax.axhline(y=epsilon, c='m', label=r'$\epsilon$')
                    ax.axvline(x=x, c='c', label='x')
                    plt.xlabel('Restricted Domain with respect to x',\
                        fontsize=20)
                    plt.xticks(fontsize=10)
                    plt.ylabel('Range of Restricted Domain',\
                        fontsize=20)
                    plt.yticks(fontsize=10)
                    plt.ylim(0, 1.02)
                    plt.xlim(0, 10 + epsilon)
                    fig.suptitle(r'$f_{n}(x) = \dfrac{nx}{1+(nx)}$',\
                        fontsize=20)
                    plt.legend(prop={'size':20})
                    plt.show()
                    
                    
                    flag = False
                    
                    
                else:
                    # We increase our index by 1
                    n += 1
                    
                    
                    # We keep the same restricted domain with vector u, but our
                    # range with this new vector v will change, since n has
                    # changed
                    v = (n*u)/(1+(n*u))
                    
                    
                    # We plot the next vector pair u and v in the same plot as 
                    # the preceding vector pairs, as well as the absolute value 
                    # of the difference of f_n(x)-f(x), where f_n(x) is the
                    # function from our sequence at n=k and f(x) is the function 
                    # to which the sequence of functions converges, for fixed x.
                    ax.plot(u, v)
                    
                    
            return f'The number of functions on the graph: {n}'
        
        
        if choose_k_or_e == 'k':
            starter = False
        
        
            # User input for x
            flag = True
            while flag:
                
                
                x_input = input('Choose a real number x between 1/2 and 10,'\
                    ' or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not x_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    x = float(x_input)
                    # When user input for x is out of specified range
                    if x < 1/2 or x > 10:
                        logging.debug(f'Your value x={x} is not in the'\
                            ' requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
                
            
            # User input for k
            flag = True
            while flag:
                
                
                k_input = input('Choose a natural number k, between'\
                    ' 100 and 1000, or press the return key to quit: ')
                
                
                # We take care of those scenarios when user input is the return
                # key
                if not k_input:
                    return 'Okay. Goodbye'
                
                
                # We take care of those scenarios when user input is
                # non-numerical
                try:
                    k = float(k_input)
                    # When user input for k is out of specified range
                    if k < 100 or k > 1000:
                        logging.debug(f'Your value k={k} is not'\
                            ' in the requested range' + f'\n')
                        continue
                    else:
                        flag = False
                except ValueError:
                    logging.debug('Really must type in a numerical value.'\
                        + f'\n')
                    continue
            
            
            # The statement below begins to assemble our figure
            fig, ax = plt.subplots(figsize=(15, 10))
            
            
            # Vector u is what defines our restricted domain of each function
            # with respect to x
            u = np.linspace(0, 10, 1000)
            
            
            # We initiate the index n with a value of 1 to simulate a
            # mathematical sequence
            n = 1
            
            
            # Vector v will serve as the range of our restricted domain defined
            # by vector u
            v = (n*u)/(1+(n*u))
            
            
            # We plot this first vector pair u and v, as well as the 
            # absolute value of the difference of f_n(x)-f(x), where f_n(x) is 
            # the function from our sequence at n=1 and f(x) is the function to 
            # which the sequence of functions converges for a fixed x.
            ax.plot(u, v)
            
            
            flag = True
            while flag:
                
                
                if abs((n*x)/(1+(n*x)) - 1) < (1/k):
                    # Completing the plot
                    ax.axvline(x=0, c='k')
                    ax.axhline(y=0, c='k')
                    ax.axhline(y=1-(1/k), c='k', label=r'$1-\dfrac{1}{k}$')
                    ax.axhline(y=1/k, c='m', label=r'$\dfrac{1}{k}$')
                    ax.axvline(x=x, c='c', label='x')
                    plt.xlabel('Restricted Domain with respect to x',\
                        fontsize=20)
                    plt.xticks(fontsize=10)
                    plt.ylabel('Range of Restricted Domain',\
                        fontsize=20)
                    plt.yticks(fontsize=10)
                    plt.ylim(0, 1.02)
                    plt.xlim(0, 10 + (1/k))
                    fig.suptitle(r'$f_{n}(x) = \dfrac{nx}{1+(nx)}$',\
                        fontsize=20)
                    plt.legend(prop={'size':20})
                    plt.show()
                    
                    
                    flag = False
                    
                    
                else:
                    # We increase our index by 1
                    n += 1
                    
                    
                    # We keep the same restricted domain with vector u, but our
                    # range with this new vector v will change, since n has
                    # changed
                    v = (n*u)/(1+(n*u))
                    
                    
                    # We plot the next vector pair u and v in the same plot as 
                    # the preceding vector pairs, as well as the absolute value 
                    # of the difference of f_n(x)-f(x), where f_n(x) is the
                    # function from our sequence at n=k and f(x) is the function 
                    # to which the sequence of functions converges, for fixed x.
                    ax.plot(u, v)
                    
                    
            return f'The number of functions on the graph: {n}'
        
        
        else:
            continue
            

nx_over_one_plus_nx()
# Out:
# Would you like to choose an arbitrarily small number based on natural number k or positive epsilon? Press k for natural number k, choose e for positive epsilon, or press return to escape the program:
# e
# Choose a real number x between 1/2 and 10, or press the return key to quit: 0.9
# Choose a small number epsilon, between 1/1000 and 1/100, or press the return key to quit: 4
#  2022-06-21 17:33:39,000 - DEBUG - Your value epsilon=4.0 is not in the requested range
# Choose a small number epsilon, between 1/1000 and 1/100, or press the return key to quit: 0.004
#  2022-06-21 17:33:50,480 - DEBUG - update_title_pos
#  2022-06-21 17:33:52,182 - DEBUG - update_title_pos
#  2022-06-21 17:33:53,031 - DEBUG - update_title_pos
#  2022-06-21 17:33:53,516 - DEBUG - update_title_pos
# 'The number of functions on the graph: 277'
